# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Make MA_{ma} columns

# %%
intervals = ['1h', '2h', '4h', '12h', '1d']
# intervals = ['1h']
for interval in intervals:
    btc_data = pd.read_csv(f'data/btc_all_{interval}_candles_from_2017.csv')
    ma_candidates = [10, 20, 30, 50, 60, 90, 100, 110, 120, 130, 140, 150, 160, 170, 180, 200, 210, 220, 230, 240, 250, 260, 270, 280, 290, 300, 450, 460, 470, 480, 490, 500, 510, 520, 530, 540, 550, 560, 1000, 1010, 1020, 1030, 1040, 1050, 1060]
    # Calculate moving averages for each candidate
    for ma in ma_candidates:
        btc_data[f'MA_{ma}'] = btc_data['close'].rolling(window=ma).mean()
    btc_data.to_csv(f'data/btc_{interval}_data_with_ma.csv', index=False)

# %%
# Display the first few rows of the updated DataFrame
print(btc_data.head(50))
# Out:
#      timestamp     open     high      low    close       volume     MA_10  \
# 0   2017-08-17  4261.48  4485.39  4200.74  4285.08   795.150377       NaN
# 1   2017-08-18  4285.08  4371.52  3938.77  4108.37  1199.888264       NaN
# 2   2017-08-19  4108.37  4184.69  3850.00  4139.98   381.309763       NaN
# 3   2017-08-20  4120.98  4211.08  4032.62  4086.29   467.083022       NaN
# 4   2017-08-21  4069.13  4119.62  3911.79  4016.00   691.743060       NaN
# 5   2017-08-22  4016.00  4104.82  3400.00  4040.00   966.684858       NaN
# 6   2017-08-23  4040.00  4265.80  4013.89  4114.01  1001.136565       NaN
# 7   2017-08-24  4147.00  4371.68  4085.01  4316.01   787.418753       NaN
# 8   2017-08-25  4316.01  4453.91  4247.48  4280.68   573.612740       NaN
# 9   2017-08-26  4280.71  4367.00  4212.41  4337.44   228.108068  4172.386
# 10  2017-08-27  4332.51  4400.00  4285.54  4310.01   350.692585  4174.879
# 11  2017-08-28  4310.01  4399.82  4124.54  4386.69   603.841616  4202.711
# ...

# %%
btc_data.columns
# Out:
# Index(['timestamp', 'open', 'high', 'low', 'close', 'volume', 'MA_10', 'MA_20',
#        'MA_30', 'MA_50', 'MA_60', 'MA_90', 'MA_100', 'MA_110', 'MA_120',
#        'MA_130', 'MA_140', 'MA_150', 'MA_160', 'MA_170', 'MA_180', 'MA_200',
#        'MA_210', 'MA_220', 'MA_230', 'MA_240', 'MA_250', 'MA_260', 'MA_270',
#        'MA_280', 'MA_290', 'MA_300', 'MA_450', 'MA_460', 'MA_470', 'MA_480',
#        'MA_490', 'MA_500', 'MA_510', 'MA_520', 'MA_530', 'MA_540', 'MA_550',
#        'MA_560', 'MA_1000', 'MA_1010', 'MA_1020', 'MA_1030', 'MA_1040',
#        'MA_1050', 'MA_1060'],
#       dtype='object')
